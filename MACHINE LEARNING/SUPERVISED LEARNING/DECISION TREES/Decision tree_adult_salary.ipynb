# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("E:\\Datasets\\Adult_salary classfication.csv")

# %%
data['Age'].head(10)
data.describe()
data.info()
data.isna()
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# Age               32561 non-null int64
# Workclass         32561 non-null object
# finalwgt          32561 non-null int64
# education         32561 non-null object
# Educationalno     32561 non-null int64
# maritualstatus    32561 non-null object
# Occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# cg                32561 non-null int64
# cl                32561 non-null int64
# hours-per-week    32561 non-null int64
# native country    32561 non-null object
# Salary            32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
#        Age          Workclass  finalwgt    education  Educationalno  \
# 0       39          State-gov     77516    Bachelors             13
# ...

# %%
dd = data

# %%
dd.columns
# Out:
# Index(['Age', 'Workclass', 'finalwgt', 'education', 'Educationalno',
#        'maritualstatus', 'Occupation', 'relationship', 'race', 'sex', 'cg',
#        'cl', 'hours-per-week', 'native country', 'Salary'],
#       dtype='object')

# %%
dd.replace(' ?',np.nan,inplace = True)

# %%
dd.head(30)
dd.shape
dd.isnull().sum()
# Out:
# Age                  0
# Workclass         1836
# finalwgt             0
# education            0
# Educationalno        0
# maritualstatus       0
# Occupation        1843
# relationship         0
# race                 0
# sex                  0
# cg                   0
# cl                   0
# hours-per-week       0
# native country     583
# Salary               0
# dtype: int64

# %%
dd.dropna(axis = 0, how = 'any')
# Out:
#        Age          Workclass  finalwgt    education  Educationalno  \
# 0       39          State-gov     77516    Bachelors             13
# 1       50   Self-emp-not-inc     83311    Bachelors             13
# 2       38            Private    215646      HS-grad              9
# 3       53            Private    234721         11th              7
# 4       28            Private    338409    Bachelors             13
# ...    ...                ...       ...          ...            ...
# 32556   27            Private    257302   Assoc-acdm             12
# 32557   40            Private    154374      HS-grad              9
# 32558   58            Private    151910      HS-grad              9
# 32559   22            Private    201490      HS-grad              9
# 32560   52       Self-emp-inc    287927      HS-grad              9
#
#             maritualstatus          Occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
dd = dd.dropna()
dd.isnull().sum()
dd.head(30)
# Out:
#     Age          Workclass  finalwgt      education  Educationalno  \
# 0    39          State-gov     77516      Bachelors             13
# 1    50   Self-emp-not-inc     83311      Bachelors             13
# 2    38            Private    215646        HS-grad              9
# 3    53            Private    234721           11th              7
# 4    28            Private    338409      Bachelors             13
# 5    37            Private    284582        Masters             14
# 6    49            Private    160187            9th              5
# 7    52   Self-emp-not-inc    209642        HS-grad              9
# 8    31            Private     45781        Masters             14
# 9    42            Private    159449      Bachelors             13
# 10   37            Private    280464   Some-college             10
# 11   30          State-gov    141297      Bachelors             13
# 12   23            Private    122272      Bachelors             13
# ...

# %%
ndd = dd.drop(['finalwgt','cg','cl','Educationalno'],axis = 1)
ndd.head()
# Out:
#    Age          Workclass   education       maritualstatus  \
# 0   39          State-gov   Bachelors        Never-married
# 1   50   Self-emp-not-inc   Bachelors   Married-civ-spouse
# 2   38            Private     HS-grad             Divorced
# 3   53            Private        11th   Married-civ-spouse
# 4   28            Private   Bachelors   Married-civ-spouse
#
#            Occupation    relationship    race      sex  hours-per-week  \
# 0        Adm-clerical   Not-in-family   White     Male              40
# 1     Exec-managerial         Husband   White     Male              13
# 2   Handlers-cleaners   Not-in-family   White     Male              40
# 3   Handlers-cleaners         Husband   Black     Male              40
# 4      Prof-specialty            Wife   Black   Female              40
#
#    native country
# 0   United-States
# 1   United-States
# 2   United-States
# 3   United-States
# 4            Cuba

# %%
ndd = pd.get_dummies(ndd)

# %%
X_train, X_test, y_train, y_test = train_test_split(ndd, y, test_size=0.2)
X_train.shape
y_train.shape
# Out:
# (24129,)

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
from sklearn import metrics
dtm = clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
y_pred
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' <=50K', ' >50K'],
#       dtype=object)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7820321564727333
